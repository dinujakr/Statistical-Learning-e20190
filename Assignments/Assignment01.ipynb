# %% [markdown]
# <a href="https://colab.research.google.com/github/dinujakr/Statistical-Learning-e20190/blob/main/Assignments/Assignment01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment 01

# %% [markdown]
# # Q1) The Probability of Shooting at a Target

# %% [markdown]
# A point is chosen at random from a disk of radius $10$. Let $A$ be the event that the point lies within $1$ unit of the boundary.
#
# 1. Model the experiment assuming the point is uniformly distributed with respect to area, and compute $P(A)$.
# 2. Model the experiment assuming the distance to the point from the center is chosen uniformly from $[0,10]$, and the direction is chosen independently and uniformly from $[0,2\pi)$ and compute $P(A)$.
# 3. Explain why the two answers differ.

# %% [markdown]
# ###01.

# %% [markdown]
# When the point is uniformly distributed w.r.t area,
#
#
# $$
# \begin{aligned}
# P(A)  &=\frac{\text{Area of the outer ring}}{\text{Area of the circle}} \\
#       &= \frac{\pi(10^2-9^2)}{\pi(10^2)} \\
#       &= 0.19
# \end{aligned}
# $$

# %% [markdown]
# ###02.

# %% [markdown]
# assuming the distance to the point from the center is chosen uniformly from $[0,10]$, and the direction is chosen independently and uniformly from $[0,2\pi)$.
#
# We define the event $A$ as the point lying within 1 unit of the boundary of the circle of radius 10. This corresponds to:
# $$
# $$
# $$
# A = \{9 \le R \le 10\}
# $$
#
# Since $R \sim \text{Uniform}(0,10)$,
# $$
# P(A) = P(9 \le R \le 10)
# $$
#
# $$
# P(A) = \frac{10 - 9}{10 - 0}
# $$
#
# $$
# P(A) = \frac{1}{10} = 0.1
# $$
#
# Therefore,
# $$
# P(A) = 0.1
# $$

# %% [markdown]
# ###03.

# %% [markdown]
# In model 2, the point is considered to be within the distance $d$ such that $d$ is uniformly in $(9 \le d \le 10)$. Then the probability is mostly concentrated in the inner rings closer to $R=9$.
# $$
# $$
# But in model 1, the probability is uniformly divided within the whole area of the outer ring.

# %% [markdown]
# # Q2) Bertrand's Paradox

# %% [markdown]
# A chord of a circle is chosen “at random.” What is the probability that its length exceeds the side length of the inscribed equilateral triangle?
#
# Show that different mathematically natural models of “random chord” lead to different answers.

# %% [markdown]
# Bertrand's paradox shows that different mathematically natural definitions of a ``random chord'' lead to different probabilities.
#
# Let the circle have radius $R$.
#
# The side length of the inscribed equilateral triangle is
#
# $$
# s=\sqrt{3}R
# $$
#
# A chord at perpendicular distance $d$ from the center has length
#
# $$
# L=2\sqrt{R^2-d^2}
# $$
#
# We require
#
# $$
# 2\sqrt{R^2-d^2}>\sqrt{3}R
# $$
#
# Squaring both sides,
#
# $$
# 4(R^2-d^2)>3R^2
# $$
#
# $$
# R^2>4d^2
# $$
#
# $$
# d<\frac{R}{2}
# $$
#
# Thus, the chord is longer than the side of the inscribed equilateral triangle iff its midpoint lies within distance \(R/2\) of the center.

# %% [markdown]
# ##Model 1: Random Endpoints on the Circumference
#
# Choose two points independently and uniformly on the circumference and join them.
#
# Fix one endpoint and let $\theta\in[0,\pi]$ be the subtended central angle.
#
# The chord length is
#
# $$
# L=2R\sin\left(\frac{\theta}{2}\right)
# $$
#
# We require
#
# $$
# 2R\sin\left(\frac{\theta}{2}\right)>\sqrt{3}R
# $$
#
# $$
# \sin\left(\frac{\theta}{2}\right)>\frac{\sqrt{3}}{2}
# $$
#
# Hence,
#
# $$
# \frac{\theta}{2}>\frac{\pi}{3}
# $$
#
# $$
# \theta>\frac{2\pi}{3}
# $$
#
# Since $\theta$ is uniformly distributed on $[0,\pi]$,
#
# $$
# P(L>\sqrt{3}R)
# =
# \frac{\pi-\frac{2\pi}{3}}{\pi}
# =
# \frac{1}{3}
# $$
#
# Therefore,
#
# $$
# {P=\frac{1}{3}}
# $$

# %% [markdown]
# ##Model 2: Midpoint Uniform Along a Radius
#
# Choose a random radius direction, then choose the midpoint of the chord uniformly along that radius.
#
# In this model, the distance \(d\) from the center is uniformly distributed on \([0,R]\).
#
# The chord is sufficiently long iff
#
# $$
# d<\frac{R}{2}
# $$
#
# Thus,
#
# $$
# P
# =
# \frac{R/2}{R}
# =
# \frac{1}{2}
# $$
#
# Therefore,
#
# $$
# {P=\frac{1}{2}}
# $$

# %% [markdown]
# ##Model 3: Midpoint Uniformly Distributed in the Disk
#
# Choose the midpoint of the chord uniformly over the area of the disk.
#
# The chord is sufficiently long iff the midpoint lies inside the concentric circle of radius \(R/2\).
#
# Hence,
#
# $$
# P
# =
# \frac{\pi(R/2)^2}{\pi R^2}
# =
# \frac{1}{4}
# $$
#
# Therefore,
#
# $$
# {P=\frac{1}{4}}
# $$
#
# ###Conclusion
#
# Different mathematically natural models of a ``random chord'' lead to different probabilities:
#
# $$
# {\frac13,\quad \frac12,\quad \frac14}
# $$
#
# Thus, Bertrand's paradox illustrates that the phrase ``choose a chord at random'' is ambiguous unless the probability model is explicitly specified.

# %% [markdown]
# #Q8) Probability of Being a Girl?

# %% [markdown]
# A family has two children. Assume each child is equally likely to be a boy or a girl, independently of the other.
#
# What is the probability that both children are girls, given that **at least one** of them is a girl?

# %% [markdown]
# Let
#
# $$
# S=\{BB,BG,GB,GG\}
# $$
#
# be the sample space, where:
#
# - \(BB\): both children are boys
# - \(BG\): older child is a boy, younger is a girl
# - \(GB\): older child is a girl, younger is a boy
# - \(GG\): both children are girls
#
# Since each child is independently equally likely to be a boy or a girl,
#
# $$
# P(BB)=P(BG)=P(GB)=P(GG)=\frac14
# $$
#
# We are given that at least one child is a girl.
#
# Thus, the possible outcomes are
#
# $$
# A=\{BG,GB,GG\}
# $$
#
# Among these three equally likely outcomes, only one corresponds to both children being girls:
#
# $$
# \{GG\}
# $$
#
# Therefore,
#
# $$
# P(\text{both girls} \mid \text{at least one girl})
# =
# \frac{1}{3}
# $$
#
# Hence,
#
# $$
# {\frac13}
# $$

# %% [markdown]
# # Q9) Information Available in a Discrete Random Variable

# %% [markdown]
# A factory inspects a product and records its quality using two different coding systems.
#
# Each product falls into exactly one of the following four categories:
#
# * $G_1$: good quality, produced on Machine 1
# * $G_2$: good quality, produced on Machine 2
# * $D_1$: defective, produced on Machine 1
# * $D_2$: defective, produced on Machine 2
#
# Assume the sample space is
#
# $$
# \Omega=\{G_1,G_2,D_1,D_2\},
# $$
#
# with probabilities
#
# $$
# P(\{G_1\})=0.50,\qquad P(\{G_2\})=0.20,\qquad P(\{D_1\})=0.10,\qquad P(\{D_2\})=0.20.
# $$
#
# Define two discrete random variables on the same probability space:
#
# * $X$ records only whether the item is good or defective:
#   $$
#   X(G_1)=0,\quad X(G_2)=0,\quad X(D_1)=1,\quad X(D_2)=1.
#   $$
#
# * $Y$ records both quality and machine:
#   $$
#   Y(G_1)=1,\quad Y(G_2)=2,\quad Y(D_1)=3,\quad Y(D_2)=4.
#   $$
#
# Answer the following.
#
# 1. Write down the probability space $(\Omega,\mathfrak F,P)$, where $\mathfrak F=\mathfrak P(\Omega)$.
#
# 2. Compute the $\sigma$-algebra generated by $X$, namely $\sigma(X)$.
#
# 3. Compute the $\sigma$-algebra generated by $Y$, namely $\sigma(Y)$.
#
# 4. Show that $\sigma(X)\subseteq \sigma(Y)$, and explain why $Y$ contains more information than $X$.
#
# 5. Find the marginal distribution of $X$.
#
# 6. Find the marginal distribution of $Y$.
#
# 7. Compute the joint probabilities
#    $$
#    P(X=0,Y=1),\quad P(X=0,Y=2),\quad P(X=1,Y=3),\quad P(X=1,Y=4).
#    $$
#
# 8. Compute the conditional probabilities
#    $$
#    P(X=1\mid Y=3),\qquad P(X=1\mid Y=4),\qquad P(Y=3\mid X=1),\qquad P(Y=4\mid X=1).
#    $$
#
# 9. Interpret the difference between conditioning on $X$ and conditioning on $Y$.
#
# 10. Explain, in words, what information is available in $\sigma(X)$ but not in $\sigma(Y)$, and what information is available in $\sigma(Y)$ but not in $\sigma(X)$.
#
# 11. Give a Python based visualization of the model.

# %% [markdown]
# ##1.
#
# $$
# \Omega=\{G_1,G_2,D_1,D_2\}.
# $$
#
# The $\sigma$-algebra is the power set
#
# $$
# \mathfrak F=\mathfrak P(\Omega).
# $$
#
# The probability measure is
#
# $$
# P(G_1)=0.50,\quad P(G_2)=0.20,\quad P(D_1)=0.10,\quad P(D_2)=0.20.
# $$
#
# Thus,
#
# $$
# (\Omega,\mathfrak F,P).
# $$

# %% [markdown]
# ##2.
# We have
#
# $$
# X^{-1}(0)=\{G_1,G_2\},\quad X^{-1}(1)=\{D_1,D_2\}.
# $$
#
# Hence
#
# $$
# \sigma(X)=\{\emptyset,\Omega,\{G_1,G_2\},\{D_1,D_2\}\}.
# $$

# %% [markdown]
# ##3.
# $\sigma$-algebra Generated by $Y$
#
# Since $Y$ assigns distinct values to each outcome,
#
# $$
# Y^{-1}(1)=\{G_1\},\;
# Y^{-1}(2)=\{G_2\},\;
# Y^{-1}(3)=\{D_1\},\;
# Y^{-1}(4)=\{D_2\}.
# $$
#
# Thus
#
# $$
# \sigma(Y)=\mathfrak P(\Omega).
# $$

# %% [markdown]
# ##4.
# Relation Between $\sigma(X)$ and $\sigma(Y)$
#
# Since
#
# $$
# \sigma(X)\subseteq \mathfrak P(\Omega)=\sigma(Y),
# $$
#
# we have
#
# $$
# \sigma(X)\subseteq \sigma(Y).
# $$
#
# So $Y$ contains more information because it identifies both machine and quality, while $X$ only identifies quality.

# %% [markdown]
# ##5.
# Marginal Distribution of $X$
#
# $$
# P(X=0)=P(G_1)+P(G_2)=0.70
# $$
#
# $$
# P(X=1)=P(D_1)+P(D_2)=0.30
# $$

# %% [markdown]
# ##6.
# Marginal Distribution of $Y$
#
# $$
# P(Y=1)=0.50,\quad P(Y=2)=0.20,\quad P(Y=3)=0.10,\quad P(Y=4)=0.20.
# $$

# %% [markdown]
# ##7.
#  Joint Probabilities
#
# $$
# P(X=0,Y=1)=0.50
# $$
#
# $$
# P(X=0,Y=2)=0.20
# $$
#
# $$
# P(X=1,Y=3)=0.10
# $$
#
# $$
# P(X=1,Y=4)=0.20
# $$

# %% [markdown]
# ##8.
# Conditional Probabilities
#
# $$
# P(X=1\mid Y=3)=\frac{0.10}{0.10}=1
# $$
#
# $$
# P(X=1\mid Y=4)=\frac{0.20}{0.20}=1
# $$
#
# $$
# P(Y=3\mid X=1)=\frac{0.10}{0.30}=\frac{1}{3}
# $$
#
# $$
# P(Y=4\mid X=1)=\frac{0.20}{0.30}=\frac{2}{3}
# $$

# %% [markdown]
# ##9.
# Conditioning on $Y$ gives complete information about both machine and quality, so outcomes become deterministic.
#
# Conditioning on $X$ only tells whether the product is good or defective, leaving uncertainty about the machine.

# %% [markdown]
# ##10.
# Information in $\sigma(X)$ and $\sigma(Y)$
#
# $\sigma(X)$ only distinguishes:
#
# - good vs defective
#
# $\sigma(Y)$ distinguishes:
#
# - good/defective AND machine identity
#
# Thus,
#
# $$
# \sigma(X)\subset \sigma(Y),
# $$
#
# and $Y$ is strictly more informative.

# %%
import matplotlib.pyplot as plt

states = ['G1','G2','D1','D2']
probs = [0.50,0.20,0.10,0.20]

plt.bar(states, probs)
plt.xlabel("States")
plt.ylabel("Probability")
plt.title("Sample Space Distribution")

for i,p in enumerate(probs):
    plt.text(i, p+0.01, str(p), ha='center')

plt.ylim(0,0.6)
plt.show()

# %% [markdown]
# # Q10) Information Available in Continuous Random Varaibles

# %% [markdown]
# A chemical plant monitors each production run using two different measurement systems.
#
# For a given run, let
#
# * $T$ be the deviation of the reactor temperature from target, measured in standardized units,
# * $P$ be the deviation of the reactor pressure from target, also measured in standardized units.
#
# Assume that $(T,P)$ is jointly continuous, with independent normal components:
#
# $$
# T \sim N(0,1), \qquad P \sim N(0,4),
# $$
#
# and $T$ and $P$ are independent.
#
# Let the underlying probability space be
#
# $$
# \Omega=\mathbb R^2, \qquad \mathfrak F=\mathfrak B(\mathbb R^2),
# $$
#
# and let $P$ be the probability measure induced by the joint density
#
# $$
# f_{T,P}(t,p)=\frac{1}{4\pi}\exp\left(-\frac{t^2}{2}-\frac{p^2}{8}\right), \qquad (t,p)\in\mathbb R^2.
# $$
#
# Define two random variables on the same probability space:
#
# * $X:\Omega\to\mathbb R$ by
#   $$
#   X(t,p)=t,
#   $$
#   so that $X$ records only the reactor temperature deviation;
#
# * $Y:\Omega\to\mathbb R^2$ by
#   $$
#   Y(t,p)=(t,p),
#   $$
#   so that $Y$ records the full sensor state: both temperature and pressure deviations.
#
# Answer the following.
#
# 1. Write down the probability space $(\Omega,\mathfrak F,P)$ explicitly.
#
# 2. Compute the $\sigma$-algebra generated by $X$, namely $\sigma(X)$.
#
# 3. Compute the $\sigma$-algebra generated by $Y$, namely $\sigma(Y)$.
#
# 4. Show that
#    $$
#    \sigma(X)\subseteq \sigma(Y),
#    $$
#    and explain why $Y$ contains more information than $X$.
#
# 5. Find the marginal density of $X$.
#
# 6. Find the marginal density of $Y$.
#
# 7. Compute the following probabilities:
#    $$
#    P(X\leq 0), \qquad P(X>1), \qquad P(Y\in (-\infty,0]\times\mathbb R), \qquad P(Y\in [ -1,1]\times[-2,2]).
#    $$
#
# 8. Compute the conditional distribution of $X$ given $Y=(t,p)$.
#
# 9. Compute the conditional distribution of $Y$ given $X=t$.
#
# 10. Explain, in words, what is known when one conditions on $X$ and what additional information becomes available when one conditions on $Y$.
#
# 11. Show that
#     $$
#     X=\pi_1\circ Y,
#     $$
#     where $\pi_1(t,p)=t$, and explain why this implies that $X$ is a measurable function of $Y$.
#
# 12. Give a Python-based visualization of the model, for example by plotting:
#
# * the joint density of $Y=(T,P)$ as a contour plot or heat map;
# * the marginal density of $X$;
# * and a diagram illustrating that $\sigma(X)$ is coarser than $\sigma(Y)$.

# %% [markdown]
# ###1)
# $$
# \Omega=\mathbb{R}^2,\quad \mathfrak{F}=\mathfrak{B}(\mathbb{R}^2)
# $$
#
# $$
# P(A)=\int_A \frac{1}{4\pi}\exp\left(-\frac{t^2}{2}-\frac{p^2}{8}\right)\,dt\,dp,
# \quad A\in \mathfrak{B}(\mathbb{R}^2)
# $$

# %% [markdown]
# ###2)
# $$
# X(t,p)=t
# $$
#
# $$
# \sigma(X)=\{X^{-1}(B): B\in \mathfrak{B}(\mathbb{R})\}
# $$
#
# $$
# X^{-1}(B)=B\times \mathbb{R}
# $$
#
# $$
# \sigma(X)=\{B\times \mathbb{R}: B\in \mathfrak{B}(\mathbb{R})\}
# $$

# %% [markdown]
# ###3)
# $$
# Y(t,p)=(t,p)
# $$
#
# $$
# \sigma(Y)=\{Y^{-1}(A): A\in \mathfrak{B}(\mathbb{R}^2)\}
# $$
#
# $$
# Y^{-1}(A)=A
# $$
#
# $$
# \sigma(Y)=\mathfrak{B}(\mathbb{R}^2)
# $$

# %% [markdown]
# ###4)
# $$
# \sigma(X)\subseteq \sigma(Y)
# $$
#
# $$
# \sigma(X)=\{B\times \mathbb{R}\}, \quad \sigma(Y)=\mathfrak{B}(\mathbb{R}^2)
# $$

# %% [markdown]
# ###5)
# $$
# X \sim \mathcal{N}(0,1)
# $$
#
# $$
# f_X(x)=\frac{1}{\sqrt{2\pi}}e^{-x^2/2}
# $$

# %% [markdown]
# ###6)
# $$
# f_Y(t,p)=\frac{1}{4\pi}\exp\left(-\frac{t^2}{2}-\frac{p^2}{8}\right)
# $$

# %% [markdown]
# ###7)
# $$
# P(X\le 0)=\frac{1}{2}
# $$
#
# $$
# P(X>1)=1-\Phi(1)
# $$
#
# $$
# P(Y\in (-\infty,0]\times\mathbb{R})=\frac{1}{2}
# $$
#
# $$
# P(Y\in [-1,1]\times[-2,2])=P(|T|\le 1)\,P(|P|\le 2)
# $$
#
# $$
# P(|T|\le 1)=2\Phi(1)-1
# $$
#
# $$
# P(|P|\le 2)=2\Phi(1)-1
# $$

# %% [markdown]
# ###8)
# $$
# X|Y=(t,p)=t
# $$
#
# $$
# P(X=t \mid Y=(t,p))=1
# $$

# %% [markdown]
# ###9)
# $$
# Y|X=t=(t,P)
# $$
#
# $$
# P \sim \mathcal{N}(0,4)
# $$
#
# $$
# f_{Y|X}(t',p|t)=\delta(t'-t)\cdot \frac{1}{\sqrt{8\pi}}e^{-p^2/8}
# $$

# %% [markdown]
# ###10)
# ###Conditioning on $X=t:$
#
# We only know the reactor temperature deviation  $T=t$.
# The pressure $P$ remains completely unknown and still random:
# $$
# P \sim \mathcal{N}(0,4).
# $$
#
# So $X$ gives a 1-dimensional partial observation of the system.
#
# ###Conditioning on $Y=(t,p)$:
#
# We know both temperature and pressure deviations exactly:
# $$
# T=t,\; P=p.
# $$
#
# No randomness remains after conditioning on $Y$.
# So $Y$ is a full state observation (complete information).

# %% [markdown]
# ###11)
# $$
# Y(t,p) = (t,p), \qquad \pi_1(t,p)=t
# $$
#
# $$
# (\pi_1 \circ Y)(t,p)
# = \pi_1(Y(t,p))
# = \pi_1(t,p)
# = t
# $$
#
# $$
# X(t,p)=t
# $$
#
# $$
# \Rightarrow X = \pi_1 \circ Y
# $$
#
# $$
# Y : (\Omega,\mathfrak{F}) \to (\mathbb{R}^2,\mathfrak{B}(\mathbb{R}^2)) \text{ is measurable}
# $$
#
# $$
# \pi_1 : (\mathbb{R}^2,\mathfrak{B}(\mathbb{R}^2)) \to (\mathbb{R},\mathfrak{B}(\mathbb{R})) \text{ is Borel measurable}
# $$
#
# $$
# \Rightarrow X = \pi_1 \circ Y \text{ is measurable w.r.t. } \sigma(Y)
# $$
#
# $$
# \Rightarrow \sigma(X) \subseteq \sigma(Y)
# $$

# %% [markdown]
# ###12)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# -----------------------------
# Grid for joint density of (T,P)
# -----------------------------
t = np.linspace(-4, 4, 300)
p = np.linspace(-8, 8, 300)
T, P = np.meshgrid(t, p)

Z = (1/(4*np.pi)) * np.exp(-T**2/2 - P**2/8)

# -----------------------------
# (1) Joint density heatmap
# -----------------------------
plt.figure()
plt.contourf(T, P, Z, levels=50)
plt.xlabel("T (temperature deviation)")
plt.ylabel("P (pressure deviation)")
plt.title("Joint Density of Y = (T, P)")
plt.colorbar()
plt.show()

# -----------------------------
# (2) Marginal density of X = T
# -----------------------------
x = np.linspace(-4, 4, 300)
fx = norm.pdf(x, 0, 1)

plt.figure()
plt.plot(x, fx)
plt.xlabel("x")
plt.ylabel("f_X(x)")
plt.title("Marginal Density of X = T ~ N(0,1)")
plt.grid(True)
plt.show()

# -----------------------------
# (3) σ-algebra intuition diagram
# -----------------------------
np.random.seed(0)

T_samp = np.random.randn(200)
P_samp = np.sqrt(4)*np.random.randn(200)

plt.figure()

# Full information (Y)
plt.scatter(T_samp, P_samp, alpha=0.4, label="σ(Y): full (T,P) plane")

# Coarse information (X): vertical projection only
plt.scatter(T_samp, np.zeros_like(T_samp),
            alpha=0.6, label="σ(X): only T observed")

plt.axhline(0, linewidth=0.5)

plt.xlabel("T")
plt.ylabel("P")
plt.title("Information Structure: σ(X) ⊂ σ(Y)")
plt.legend()
plt.show()
