# %% [markdown]
# <a href="https://colab.research.google.com/github/dinujakr/Statistical-Learning-e20190/blob/main/Assignments/conditional_expectation_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Q1) Prediction of fraudulent transactions

# %% [markdown]
# A bank monitors credit-card transactions for possible fraud.
#
# For each transaction, let the sample space be
#
# $$
# \Omega=\{\omega_1,\omega_2,\omega_3,\omega_4\},
# $$
#
# where:
#
# * $\omega_1$: low-risk customer, legitimate transaction,
# * $\omega_2$: low-risk customer, fraudulent transaction,
# * $\omega_3$: high-risk customer, legitimate transaction,
# * $\omega_4$: high-risk customer, fraudulent transaction.
#
# Assume the probabilities are
#
# $$
# P(\{\omega_1\})=0.50,\qquad
# P(\{\omega_2\})=0.10,\qquad
# P(\{\omega_3\})=0.20,\qquad
# P(\{\omega_4\})=0.20.
# $$
#
# Let $X:\Omega\to\mathbb R$ denote the fraud indicator:
#
# $$
# X(\omega_1)=0,\qquad
# X(\omega_2)=1,\qquad
# X(\omega_3)=0,\qquad
# X(\omega_4)=1.
# $$
#
# Thus $X=1$ means the transaction is fraudulent, and $X=0$ means it is legitimate.
#
# Now suppose the bank does not observe the full outcome $\omega$, but only the customer's risk class. Define $Y:\Omega\to\mathbb R$ by
#
# $$
# Y(\omega_1)=0,\qquad
# Y(\omega_2)=0,\qquad
# Y(\omega_3)=1,\qquad
# Y(\omega_4)=1.
# $$
#
# Thus:
#
# * $Y=0$ means “low-risk customer,”
# * $Y=1$ means “high-risk customer.”
#
# Answer the following.

# %% [markdown]
# 1. Write down the probability space $(\Omega,\mathfrak F,P)$, where $\mathfrak F=\mathfrak P(\Omega)$.
#
# The probability space is
#
# $$
# (\Omega,\mathfrak F,P),
# $$
#
# where
#
# $$
# \Omega=\{\omega_1,\omega_2,\omega_3,\omega_4\},
# $$
#
# and
#
# $$
# \mathfrak F=\mathfrak P(\Omega).
# $$
#
# Thus,
#
# $$
# \mathfrak F=\{\emptyset,\{\omega_1\},\{\omega_2\},\{\omega_3\},\{\omega_4\},\ldots,\Omega\}.
# $$
#
# The probability measure is defined by
#
# $$
# P(\{\omega_1\})=0.50,
# $$
#
# $$
# P(\{\omega_2\})=0.10,
# $$
#
# $$
# P(\{\omega_3\})=0.20,
# $$
#
# $$
# P(\{\omega_4\})=0.20.
# $$

# %% [markdown]
# 2. Compute the $\sigma$-algebra generated by $Y$, namely $\sigma(Y)$.
#
# Since
#
# $$
# Y(\omega_1)=Y(\omega_2)=0,
# $$
#
# and
#
# $$
# Y(\omega_3)=Y(\omega_4)=1,
# $$
#
# the partition induced by $Y$ is
#
# $$
# \{\omega_1,\omega_2\},\qquad\{\omega_3,\omega_4\}.
# $$
#
# Therefore,
#
# $$
# \sigma(Y)=\{\emptyset,\{\omega_1,\omega_2\},\{\omega_3,\omega_4\},\Omega\}.
# $$

# %% [markdown]
# 3. Explain why $E[X\mid Y]$ must be $\sigma(Y)$-measurable, and therefore must be constant on the sets $\{ \omega_1,\omega_2\}$ and $\{\omega_3,\omega_4\}$.
#
#
# By definition,
#
# $$
# E[X\mid Y]
# $$
#
# must be measurable with respect to
#
# $$
# \sigma(Y).
# $$
#
# A $\sigma(Y)$-measurable random variable can only distinguish sets contained in $\sigma(Y)$.
#
# Since $\sigma(Y)$ contains only the sets
#
# $$
# \{\omega_1,\omega_2\}
# \quad \text{and} \quad
# \{\omega_3,\omega_4\},
# $$
#
# the conditional expectation must be constant on each block of this partition.
#
# Hence,
#
# $$
# E[X\mid Y]
# =
# a\,\mathbb 1_{\{\omega_1,\omega_2\}}
# +
# b\,\mathbb 1_{\{\omega_3,\omega_4\}}
# $$
#
# for some constants $a,b$.

# %% [markdown]
# 4. Compute $E[X\mid Y]$ explicitly and show that
#
# $$
# E[X\mid Y]= \frac{1}{6} \mathbb{1}_{\{Y=0\}} + \frac{1}{2} \mathbb{1}_{\{Y=1\}}
# $$
#
#
#
# For the low-risk group,
#
# $$
# P(Y=0)=0.50+0.10=0.60.
# $$
#
# Also,
#
# $$
# P(X=1,Y=0)=0.10.
# $$
#
# Hence,
#
# $$
# E[X\mid Y=0]=P(X=1\mid Y=0)=\frac{0.10}{0.60}=\frac16.
# $$
#
# For the high-risk group,
#
# $$
# P(Y=1)=0.20+0.20=0.40,
# $$
#
# and
#
# $$
# P(X=1,Y=1)=0.20.
# $$
#
# Thus,
#
# $$
# E[X\mid Y=1]=P(X=1\mid Y=1)=\frac{0.20}{0.40}=\frac12.
# $$
#
# Therefore,
#
# $$
# E[X\mid Y]=\frac16\,\mathbb 1_{\{Y=0\}}+\frac12\,\mathbb 1_{\{Y=1\}}.
# $$

# %% [markdown]
# 5. Verify the defining property of conditional expectation by checking that for every set $A\in\sigma(Y)$,
#
# $$
# \int_A E[X\mid Y]\,dP=\int_A X\,dP.
# $$
#
# for all
#
# $$
# A\in\sigma(Y).
# $$
#
# Take
#
# $$
# A=\{\omega_1,\omega_2\}.
# $$
#
# Then,
#
# $$
# \int_A E[X\mid Y]\,dP=\frac16(0.50+0.10)=0.10.
# $$
#
# Also,
#
# $$
# \int_A X\,dP=0(0.50)+1(0.10)=0.10.
# $$
#
# Now take
#
# $$
# A=\{\omega_3,\omega_4\}.
# $$
#
# Then,
#
# $$
# \int_A E[X\mid Y]\,dP=\frac12(0.20+0.20)=0.20.
# $$
#
# Also,
#
# $$
# \int_A X\,dP=0(0.20)+1(0.20)=0.20.
# $$
#
# Hence the defining property holds.

# %% [markdown]
# 6. Find the Conditional PMF $p_{X|Y}(x \mid y)$.
#
# For $Y=0$,
#
# $$
# p_{X|Y}(0\mid0)
# =
# \frac{0.50}{0.60}
# =
# \frac56,
# $$
#
# $$
# p_{X|Y}(1\mid0)
# =
# \frac{0.10}{0.60}
# =
# \frac16.
# $$
#
# For $Y=1$,
#
# $$
# p_{X|Y}(0\mid1)
# =
# \frac{0.20}{0.40}
# =
# \frac12,
# $$
#
# $$
# p_{X|Y}(1\mid1)
# =
# \frac{0.20}{0.40}
# =
# \frac12.
# $$
#
# Thus,
#
# $$
# p_{X|Y}(x\mid y)=
# \begin{cases}
# \dfrac56, & x=0,y=0,\\
# \dfrac16, & x=1,y=0,\\
# \dfrac12, & x=0,y=1,\\
# \dfrac12, & x=1,y=1.
# \end{cases}
# $$

# %% [markdown]
# 7. Verify the identity:
# $$\mathbb{E}[X\mid Y=y] = \sum_{x \in \{0,1\}} x \cdot p_{X|Y}(x \mid y)$$
#
# For $y=0$,
# $$
# p_{X|Y}(1\mid0)=\frac{P(X=1,Y=0)}{P(Y=0)}=\frac{0.10}{0.60}=\frac16
# $$
#
#
# $$
# \sum_{x=0}^1 x\,p_{X|Y}(x\mid0)
# =
# 0\cdot\frac56
# +
# 1\cdot\frac16
# =
# \frac16.
# $$
#
# For $y=1$,
#
# $$
# \sum_{x=0}^1 x\,p_{X|Y}(x\mid1)
# =
# 0\cdot\frac12
# +
# 1\cdot\frac12
# =
# \frac12.
# $$
#
# Thus the identity is verified.

# %% [markdown]
# 8. Calculate the **Mean Square Error (MSE)**
#
# Using the estimator
#
# $$
# \hat X=E[X\mid Y],
# $$
#
# the mean square error is
#
# $$
# \text{MSE}=E[(X-E[X\mid Y])^2].
# $$
#
# Using conditional variance,
#
# $$
# \text{MSE}=E[\operatorname{Var}(X\mid Y)].
# $$
#
# For $Y=0$,
#
# $$
# \operatorname{Var}(X\mid Y=0)=\frac16\left(1-\frac16\right)=\frac{5}{36}.
# $$
#
# For $Y=1$,
#
# $$
# \operatorname{Var}(X\mid Y=1)=\frac12\left(1-\frac12\right)=\frac14.
# $$
#
# Hence,
#
# $$
# \text{MSE}
# =
# 0.60\cdot\frac{5}{36}
# +
# 0.40\cdot\frac14.
# $$
#
# Therefore,
#
# $$
# \text{MSE}
# =
# \frac{1}{12}
# +
# \frac{1}{10}
# =
# \frac{11}{60}.
# $$
#
# Thus,
#
# $$
# \text{MSE}=\frac{11}{60}\approx0.1833
# $$

# %% [markdown]
# 9. How would the **Mean Square Error (MSE)** change if the bank decided to ignore the customer risk class $Y$ and instead used the global average fraud rate ($E[X] = 0.30$) as a constant estimate for every transaction? Calculate this error and explain its relationship to the **Law of Total Variance**.
#
#
# $$
# E[X]=0(0.70)+1(0.30)=0.30
# $$
#
# If the bank ignores $Y$, it uses the constant estimator
#
# $$
# \hat X=0.30.
# $$
#
# Then,
#
# $$
# \text{MSE}=E[(X-0.30)^2].
# $$
#
# Since $X$ is Bernoulli$(0.30)$,
#
# $$
# \operatorname{Var}(X)=0.30(0.70)=0.21
# $$
#
# Hence,
#
# $$
# \text{MSE}=0.21
# $$
#
# The Law of Total Variance states that
#
# $$
# \operatorname{Var}(X)=E[\operatorname{Var}(X\mid Y)]+\operatorname{Var}(E[X\mid Y]).
# $$
#
# We found
#
# $$
# \operatorname{Var}(X)=0.21,
# $$
#
# and
#
# $$
# E[\operatorname{Var}(X\mid Y)]=\frac{11}{60}\approx0.1833.
# $$
#
# Therefore,
#
# $$
# \operatorname{Var}(E[X\mid Y])=0.21-0.1833=0.0267.
# $$
#
# Thus, observing $Y$ reduces prediction error by the explained variance.

# %% [markdown]
# 10. Using the joint distribution of $(X, Y)$ derived from the sample space:
#
#     a) Compute the entropy $H(X)$, representing the bank's initial uncertainty regarding fraud.
#
#     b) Compute the conditional entropy $H(X \mid Y)$, representing the uncertainty remaining after the customer's risk class is revealed.
#
#     c) Calculate the Mutual Information $I(X; Y)$.
#
#     d) Based on these values, what percentage of the total uncertainty about fraud is removed by knowing the customer's risk class?
#
# (a). Entropy $H(X)$
#
#
# Since
#
# $$
# P(X=1)=0.30,\qquad P(X=0)=0.70,
# $$
#
# the entropy is
#
# $$
# H(X)=-\sum_x p(x)\log_2 p(x)
# $$
#
# Thus,
#
# $$
# H(X)=-0.70\log_2(0.70)-0.30\log_2(0.30)
# $$
#
# Therefore,
#
# $$
# H(X)\approx0.8813\text{ bits}
# $$
#
# $ $
#
# (b) Conditional Entropy $H(X\mid Y)$
#
# Using
#
# $$
# H(X\mid Y)=\sum_y P(Y=y)H(X\mid Y=y),
# $$
#
# we compute
#
# $$
# H(X\mid Y=0)=-\frac56\log_2\frac56-\frac16\log_2\frac16\approx0.6500
# $$
#
# Also,
#
# $$
# H(X\mid Y=1)=1
# $$
#
# Hence,
#
# $$
# H(X\mid Y)=0.60(0.6500)+0.40(1)
# $$
#
# Therefore,
#
# $$
# H(X\mid Y)\approx0.7900\text{ bits}
# $$
#
# $ $
#
# (c) Mutual Information $I(X;Y)$
#
#
# By definition,
#
# $$
# I(X;Y)=H(X)-H(X\mid Y)
# $$
#
# Thus,
#
# $$
# I(X;Y)=0.8813-0.7900
# $$
#
# Therefore,
#
# $$
# I(X;Y)\approx0.0913\text{ bits}
# $$
#
# $ $
#
#
# (d) Percentage Reduction in Uncertainty
#
#
# $$
# \frac{I(X;Y)}{H(X)}\times100\%.
# $$
#
# Thus,
#
# $$
# \frac{0.0913}{0.8813}\times100\%
# \approx10.36\%.
# $$
#
# Therefore, knowing the customer's risk class removes approximately
#
# $$
# 10.36\%
# $$
#
# of the uncertainty regarding fraud.

# %% [markdown]
# # Q2) Conditional Density of the Multivariate Gaussian

# %% [markdown]
# Let $\mathbf{Z}$ be the concatenated random matrix
# $\mathbf{Z} = \begin{bmatrix} \mathbf{X} \\ \mathbf{Y} \end{bmatrix} \in \mathbb{R}^{n+m}$.
#
#
# The random variable $\mathbf{Z}$ is said to have a **joint multivariate normal distribution** if every linear combination of its components follows a univariate normal distribution.
#
# For $\mathbf{Z}$ to possess a **joint density function** (meaning its distribution is absolutely continuous with respect to the Lebesgue measure on $\mathbb{R}^{n+m}$), its covariance matrix must be non-singular (positive definite).
#
#
# The joint density function $f_{\mathbf{X}, \mathbf{Y}}(\mathbf{z})$ for $\mathbf{z} \in \mathbb{R}^{n+m}$ is given by:
#
# $$f_{\mathbf{X}, \mathbf{Y}}(\mathbf{z}) = \frac{1}{\sqrt{(2\pi)^{n+m} |\boldsymbol{\Sigma}|}} \exp\left( -\frac{1}{2} (\mathbf{z} - \boldsymbol{\mu})^T \boldsymbol{\Sigma}^{-1} (\mathbf{z} - \boldsymbol{\mu}) \right).$$
#
# Here:
#
# * **Mean ($\boldsymbol{\mu}$):** $\boldsymbol{\mu} = E[\mathbf{Z}] = \begin{bmatrix} \boldsymbol{\mu}_X \\ \boldsymbol{\mu}_Y \end{bmatrix} \in \mathbb{R}^{n+m}$, where $\boldsymbol{\mu}_X \in \mathbb{R}^n$ and $\boldsymbol{\mu}_Y \in \mathbb{R}^m$.
# * **Covariance Matrix ($\boldsymbol{\Sigma}$):** A symmetric, positive definite matrix $\boldsymbol{\Sigma} \in \mathbb{R}^{(n+m) \times (n+m)}$ partitioned as:
# $$\boldsymbol{\Sigma} = \begin{bmatrix} \boldsymbol{\Sigma}_{XX} & \boldsymbol{\Sigma}_{XY} \\ \boldsymbol{\Sigma}_{YX} & \boldsymbol{\Sigma}_{YY} \end{bmatrix}$$
#     * $\boldsymbol{\Sigma}_{XX} = \text{Var}(\mathbf{X})$ (size $n \times n$)
#     * $\boldsymbol{\Sigma}_{YY} = \text{Var}(\mathbf{Y})$ (size $m \times m$)
#     * $\boldsymbol{\Sigma}_{XY} = \text{Cov}(\mathbf{X}, \mathbf{Y}) = \boldsymbol{\Sigma}_{YX}^T$ (size $n \times m$)
# * **Determinant ($|\boldsymbol{\Sigma}|$):** The normalization factor ensuring the total integral is 1.
#
# 1. Show that the conditional distribution is given by $f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y})$
#
# $$f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x} \mid \mathbf{y}) = \frac{1}{\sqrt{(2\pi)^n |\mathbf{S}_{XX}|}} \exp\left( -\frac{1}{2} (\mathbf{x} - \boldsymbol{\mu}^*)^T \boldsymbol{\Sigma}_{X\mid Y}^{-1} (\mathbf{x} - \boldsymbol{\mu}^*) \right),$$
# where
# * $\boldsymbol{\Sigma}_{X\mid Y} = \boldsymbol{\Sigma}_{XX} - \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}$
# * $\boldsymbol{\mu}^* = \boldsymbol{\mu}_x + \boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y} - \boldsymbol{\mu}_y)$

# %% [markdown]
# $$
# \mathbf{Z}=\begin{bmatrix}\mathbf{X}\\ \mathbf{Y}\end{bmatrix}\sim \mathcal{N}\left(
# \begin{bmatrix}\boldsymbol{\mu}_X\\ \boldsymbol{\mu}_Y\end{bmatrix},
# \begin{bmatrix}
# \boldsymbol{\Sigma}_{XX} & \boldsymbol{\Sigma}_{XY}\\
# \boldsymbol{\Sigma}_{YX} & \boldsymbol{\Sigma}_{YY}
# \end{bmatrix}
# \right)
# $$
#
# $$
# f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x}|\mathbf{y})
# =\frac{f_{\mathbf{X},\mathbf{Y}}(\mathbf{x},\mathbf{y})}{f_{\mathbf{Y}}(\mathbf{y})}
# $$
#
# $$
# f_{\mathbf{X},\mathbf{Y}}(\mathbf{x},\mathbf{y})
# =\frac{1}{\sqrt{(2\pi)^{n+m}|\boldsymbol{\Sigma}|}}
# \exp\left(
# -\frac12
# \begin{bmatrix}\mathbf{x}-\boldsymbol{\mu}_X\\ \mathbf{y}-\boldsymbol{\mu}_Y\end{bmatrix}^T
# \boldsymbol{\Sigma}^{-1}
# \begin{bmatrix}\mathbf{x}-\boldsymbol{\mu}_X\\ \mathbf{y}-\boldsymbol{\mu}_Y\end{bmatrix}
# \right)
# $$
#
# $$
# f_{\mathbf{Y}}(\mathbf{y})
# =\frac{1}{\sqrt{(2\pi)^m|\boldsymbol{\Sigma}_{YY}|}}
# \exp\left(
# -\frac12(\mathbf{y}-\boldsymbol{\mu}_Y)^T
# \boldsymbol{\Sigma}_{YY}^{-1}
# (\mathbf{y}-\boldsymbol{\mu}_Y)
# \right)
# $$
#
# $$
# f_{\mathbf{X}|\mathbf{Y}}(\mathbf{x}|\mathbf{y})
# =\frac{1}{\sqrt{(2\pi)^n|\boldsymbol{\Sigma}_{X|Y}|}}
# \exp\left(
# -\frac12(\mathbf{x}-\boldsymbol{\mu}^*)^T
# \boldsymbol{\Sigma}_{X|Y}^{-1}
# (\mathbf{x}-\boldsymbol{\mu}^*)
# \right)
# $$
#
# $$
# \boldsymbol{\mu}^*
# =\boldsymbol{\mu}_X+\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}(\mathbf{y}-\boldsymbol{\mu}_Y)
# $$
#
# $$
# \boldsymbol{\Sigma}_{X|Y}
# =\boldsymbol{\Sigma}_{XX}-\boldsymbol{\Sigma}_{XY}\boldsymbol{\Sigma}_{YY}^{-1}\boldsymbol{\Sigma}_{YX}
# $$
#
# $$
# \mathbf{X}|\mathbf{Y}=\mathbf{y}\sim \mathcal{N}(\boldsymbol{\mu}^*,\boldsymbol{\Sigma}_{X|Y})
# $$

# %% [markdown]
# # Q3) Continuous Fault Monitoring of a Spindle Motor

# %% [markdown]
# A factory monitors the health of a high-speed CNC spindle. The critical variable is the **Internal Temperature ($X$)**, but because the motor is sealed, they can only observe the **Total Spindle Power ($Y$)**.
#
# **The Setup:**
# 1.  **Hidden Temperature ($X$):** The standardized temperature deviation follows a standard normal distribution:
#     $$X \sim \mathscr{N}(0, 1)$$
# 2.  **Mechanical Load ($Q$):** The torque required to cut material creates "noise" in the power reading. It is independent of temperature and follows:
#     $$Q \sim \mathscr{N}(0, 4)$$
# 3.  **The Measurement ($Y$):** The power sensor $Y$ measures the combined effect of thermal load and mechanical torque:
# $$Y = X + Q$$
#
# ---
#
# **Answer the followings:**

# %% [markdown]
# **1. Joint Distribution**
# Identify the distribution of the random varaible $(X, Y)$.
# * Show that $Y \sim \mathscr{N}(0, 5)$.
# * Find the covariance $\text{Cov}(X, Y)$.
#
# $$
# X \sim \mathcal{N}(0,1),\quad Q \sim \mathcal{N}(0,4),\quad X \perp Q,\quad Y=X+Q
# $$
# $$
# Y=X+Q
# $$
#
# Since
# $$
# X \sim \mathcal{N}(0,1),\quad Q \sim \mathcal{N}(0,4),\quad X \perp Q,
# $$
#
# a linear combination of independent normal random variables is also normal, hence
# $$
# Y \sim \mathcal{N}\big(E[X]+E[Q],\ \operatorname{Var}(X)+\operatorname{Var}(Q)\big)
# $$
#
# Compute mean:
# $$
# E[Y]=E[X]+E[Q]=0+0=0
# $$
#
# Compute variance:
# $$
# \operatorname{Var}(Y)=\operatorname{Var}(X+Q)
# =\operatorname{Var}(X)+\operatorname{Var}(Q)+2\operatorname{Cov}(X,Q)
# $$
#
# Since $X \perp Q$,
# $$
# \operatorname{Cov}(X,Q)=0
# $$
#
# Thus,
# $$
# \operatorname{Var}(Y)=1+4=5
# $$
#
# Therefore,
# $$
# Y \sim \mathcal{N}(0,5)
# $$
#
# $$
# (X,Y)\sim \mathcal{N}\left(
# \begin{bmatrix}0\\0\end{bmatrix},
# \begin{bmatrix}
# 1 & 1\\
# 1 & 5
# \end{bmatrix}
# \right)
# $$
#
#
# $$
# \operatorname{Cov}(X,Y)=\operatorname{Cov}(X,X+Q)
# $$
#
# Using linearity of covariance,
# $$
# \operatorname{Cov}(X,X+Q)=\operatorname{Cov}(X,X)+\operatorname{Cov}(X,Q)
# $$
#
# Now,
# $$
# \operatorname{Cov}(X,X)=\operatorname{Var}(X)=1
# $$
#
# and since $X \perp Q$,
# $$
# \operatorname{Cov}(X,Q)=0
# $$
#
# Therefore,
# $$
# \operatorname{Cov}(X,Y)=1
# $$

# %% [markdown]
# **2. Information Geometry**
# Explain why $X$ is **not** $\sigma(Y)$-measurable. In practical terms, if the power meter shows $Y = 5$, why can't the engineer know for certain if the motor is overheating ($X$ is high) or if the material being cut is simply very hard ($Q$ is high)?
#
# $$
# Y = X + Q
# $$
#
# $$
# \sigma(Y) = \sigma(X+Q)
# $$
#
# For $X$ to be $\sigma(Y)$-measurable, there must exist a deterministic function $g$ such that
# $$
# X = g(Y)
# $$
#
# However,
# $$
# Y = X + Q \;\Rightarrow\; X = Y - Q
# $$
#
# Since $Q \sim \mathcal{N}(0,4)$ is an independent random variable not determined by $Y$, the value of $Q$ cannot be recovered from $Y$ alone.
#
# Hence multiple decompositions are possible:
# $$
# Y=5 \Rightarrow (X,Q) \in \{(5,0),(4,1),(3,2),(0,5),(-1,6),\dots\}
# $$
#
# Therefore $X$ is not uniquely determined by $Y$, implying
# $$
# X \notin \sigma(Y)
# $$
#
# Practical interpretation:
# $$
# Y=5 \text{ is a single observed power level, but it conflates thermal load } (X)
# \text{ and mechanical load } (Q)
# $$
#
# So the same reading $Y=5$ can arise from:
# $$
# \text{high temperature (large }X\text{), low torque (small }Q)
# $$
# or
# $$
# \text{normal temperature (small }X\text{), high torque (large }Q)
# $$
#
# Thus the observation $Y$ does not contain enough information to disambiguate $X$.

# %% [markdown]
# **3. Conditional Expectation (The Best Estimate)**
# Compute the conditional expectation $E[X \mid Y]$.
# * Using the property for joint normals: $E[X \mid Y = y] = \mu_X + \frac{\text{Cov}(X,Y)}{\text{Var}(Y)}(y - \mu_Y)$.
# * Express this as a "signal-to-total-variance" ratio.
#
# $$
# E[X \mid Y=y] = \mu_X + \frac{\operatorname{Cov}(X,Y)}{\operatorname{Var}(Y)}(y-\mu_Y)
# $$
#
# From the given model,
# $$
# \mu_X=0,\quad \mu_Y=0
# $$
#
# $$
# \operatorname{Cov}(X,Y)=1,\quad \operatorname{Var}(Y)=5
# $$
#
# $$
# E[X \mid Y=y] = 0 + \frac{1}{5}y
# $$
#
# Hence,
# $$
# E[X \mid Y]=\frac{1}{5}Y
# $$
#
# $\textbf{Signal-to-total-variance interpretation:}$
#
# $$
# \frac{\operatorname{Cov}(X,Y)}{\operatorname{Var}(Y)}
# =
# \frac{\sigma_X^2}{\sigma_X^2+\sigma_Q^2}
# =
# \frac{1}{1+4}
# =
# \frac{1}{5}
# $$
#
# Thus,
# $$
# E[X \mid Y]=\frac{\sigma_X^2}{\sigma_X^2+\sigma_Q^2}\,Y
# $$

# %% [markdown]
# **4. Verification of the Residual**
# Let $\widehat{X} = E[X \mid Y]$. Define the estimation error (residual) as $Z = X - \widehat{X}$.
# * Prove that $E[Z] = 0$.
# * Verify that the error $Z$ is uncorrelated with the observation $Y$ (the Orthogonality Principle).
#
# $$
# \widehat{X}=E[X|Y]=\frac{1}{5}Y,\quad Z=X-\widehat{X}
# $$
#
# $$
# E[Z]=E[X]-E[\widehat{X}]=0-0=0
# $$
#
# $$
# \operatorname{Cov}(Z,Y)=\operatorname{Cov}(X-\tfrac{1}{5}Y,Y)
# $$
#
# $$
# =\operatorname{Cov}(X,Y)-\tfrac{1}{5}\operatorname{Var}(Y)
# $$
#
# $$
# =1-\tfrac{1}{5}\cdot 5=0
# $$
#
# $$
# \Rightarrow Z \perp Y \ \text{(uncorrelated)}
# $$

# %% [markdown]
# **5. Information Theory: Differential Entropy**
# * Compute the differential entropy $h(X)$.
# * Compute the conditional differential entropy $h(X \mid Y)$.
# * *Note: The variance of the conditional distribution $(X \mid Y=y)$ is given by $\sigma_{X|Y}^2 = \sigma_X^2 - \frac{\text{Cov}(X,Y)^2}{\text{Var}(Y)}$.*
#
#
# $$
# X \sim \mathcal{N}(0,1)
# $$
#
# $$
# h(X)=\frac{1}{2}\log(2\pi e\sigma_X^2)
# $$
#
# $$
# h(X)=\frac{1}{2}\log(2\pi e\cdot 1)
# $$
#
# $$
# h(X)=\frac{1}{2}\log(2\pi e)
# $$
#
# -
#
# $$
# \sigma_{X|Y}^2=\sigma_X^2-\frac{\operatorname{Cov}(X,Y)^2}{\operatorname{Var}(Y)}
# $$
#
# $$
# \sigma_{X|Y}^2=1-\frac{1^2}{5}=\frac{4}{5}
# $$
#
#
# $$
# X|Y \sim \mathcal{N}\left(E[X|Y],\sigma_{X|Y}^2\right)
# $$
#
# $$
# h(X|Y)=\frac{1}{2}\log\left(2\pi e\,\sigma_{X|Y}^2\right)
# $$
#
# $$
# h(X|Y)=\frac{1}{2}\log\left(2\pi e\cdot \frac{4}{5}\right)
# $$

# %% [markdown]
# **6. Mutual Information**
# Calculate $I(X; Y) = h(X) - h(X \mid Y)$.
# * What percentage of the "uncertainty" about the temperature is removed by observing the power meter?
# * How would this change if the mechanical noise $Q$ had a variance of $100$ instead of $4$?
#
# $$
# I(X;Y)=h(X)-h(X\mid Y)
# $$
#
# $$
# h(X)=\frac{1}{2}\log(2\pi e)
# $$
#
# $$
# h(X\mid Y)=\frac{1}{2}\log\left(2\pi e\cdot \frac{4}{5}\right)
# $$
#
# -
#
# $$
# I(X;Y)=\frac{1}{2}\log(2\pi e)-\frac{1}{2}\log\left(2\pi e\cdot \frac{4}{5}\right)
# $$
#
# $$
# I(X;Y)=\frac{1}{2}\log\left(\frac{1}{4/5}\right)
# $$
#
# $$
# I(X;Y)=\frac{1}{2}\log\left(\frac{5}{4}\right)
# $$
#
#
#
# Percentage of uncertainty removed
#
# $$
# \text{Fraction removed}=\frac{I(X;Y)}{h(X)}\times 100\%
# $$
#
# $$
# =\frac{\frac{1}{2}\log(5/4)}{\frac{1}{2}\log(2\pi e)}\times 100\%
# $$
#
# $$
# =\frac{\log(5/4)}{\log(2\pi e)}\times 100\%
# $$
#
# --
#
# Effect of increasing noise variance to $\sigma_Q^2=100$
#
# $$
# \operatorname{Var}(Y)=1+100=101
# $$
#
# $$
# \sigma_{X|Y}^2=1-\frac{1}{101}=\frac{100}{101}
# $$
#
# $$
# I(X;Y)=\frac{1}{2}\log\left(\frac{1}{100/101}\right)
# $$
#
# $$
# I(X;Y)=\frac{1}{2}\log\left(\frac{101}{100}\right)
# $$
#
# $$
# I(X;Y)\approx 0
# $$
#
# As noise variance increases, $I(X;Y)\downarrow 0,\$ so almost no uncertainty is removed.

# %% [markdown]
# **7. Diagnostic Interpretation**
# The factory manager says: *"Since $Y = X + Q$, our best estimate of temperature should just be $Y$ itself."*
# Using your result from Question 3, explain why $Y$ is a **biased** estimator of $X$ and why $E[X \mid Y]$ "shrinks" the measurement toward the mean (zero).
#
# $$
# Y = X + Q,\quad E[X]=0,\quad E[Q]=0
# $$
#
# A natural (but naive) estimator is:
# $$
# \hat{X}=Y
# $$
#
# Check bias:
# $$
# \text{Bias} = E[\hat{X}-X] = E[Y-X]
# $$
#
# $$
# =E[(X+Q)-X]=E[Q]=0
# $$
#
# So $Y$ is $\textbf{unbiased}$, but it is not optimal.
#
#
# $$
# \operatorname{Var}(Y)=\operatorname{Var}(X)+\operatorname{Var}(Q)=5
# $$
#
# So $Y$ contains large noise variance from $Q$, meaning:
# $$
# Y = \text{signal} + \text{high uncertainty noise}
# $$
#
# --
#
#
#
# From Question 3:
# $$
# E[X\mid Y]=\frac{1}{5}Y
# $$
#
# --
#
# Why “shrinkage” happens
#
# Rewrite:
# $$
# E[X\mid Y]=\frac{\sigma_X^2}{\sigma_X^2+\sigma_Q^2}Y
# $$
#
# Since:
# $$
# \frac{\sigma_X^2}{\sigma_X^2+\sigma_Q^2}=\frac{1}{5}<1
# $$
#
# we get:
# $$
# E[X\mid Y] < Y \quad \text{(in magnitude)}
# $$
#
# --
#
# Interpretation
#
# - $Y$ overreacts to noise $Q$
# - Large observed values of $Y$ are partly due to noise, not true temperature
# - The conditional expectation pulls estimates back toward:
# $$
# E[X]=0
# $$
#
#
# $[X\mid Y]$ is the minimum MSE estimator and reduces noise-induced overestimation,
#
# while $Y$ is too noisy and therefore “too extreme” compared to the true signal.
